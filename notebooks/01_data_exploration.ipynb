# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# #Load the dataset

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/BNG_dataset/Bengaluru_dataset.csv"

df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
print("Shape:", df.shape)
# Out:
# Dataset loaded successfully!
# Shape: (100881, 22)

# %% [markdown]
# #Inspect the columns and first records

# %%
print("Columns:")
print(df.columns.tolist())

print("\nFirst 5 records:")
display(df.head())
# Out:
# Columns:
# ['_id', 'SlNo', 'Station', 'Agency', 'State LGD Code', 'State', 'District LGD Code', 'District', 'Tehsil', 'Block', 'Village', 'River', 'Basin', 'Tributary', 'Subtributary', 'SubSubtributary', 'Local River', 'Latitude', 'Longitude', 'RL_MSL', 'Data Acquisition Time', 'Groundwater Level Telemetry 6 Hourly (meter)']
#
# First 5 records:
#        _id     SlNo      Station        Agency  State LGD Code      State  \
# 0  4553464  4553464  Rajanukunte  Karnataka GW              29  Karnataka
# 1  4553465  4553465  Rajanukunte  Karnataka GW              29  Karnataka
# 2  4553466  4553466  Rajanukunte  Karnataka GW              29  Karnataka
# 3  4553467  4553467  Rajanukunte  Karnataka GW              29  Karnataka
# 4  4553468  4553468  Rajanukunte  Karnataka GW              29  Karnataka
#
#    District LGD Code         District     Tehsil      Block      Village  \
# 0                525  Bangalore Urban  Yelahanka  Yelahanka  Rajanukunte
# 1                525  Bangalore Urban  Yelahanka  Yelahanka  Rajanukunte
# 2                525  Bangalore Urban  Yelahanka  Yelahanka  Rajanukunte
# 3                525  Bangalore Urban  Yelahanka  Yelahanka  Rajanukunte
# 4                525  Bangalore Urban  Yelahanka  Yelahanka  Rajanukunte
#
#   River Basin Tributary Subtributary SubSubtributary Local River  Latitude  \
# 0     -     -         -            -               -           -     13.17
# 1     -     -         -            -               -           -     13.17
# 2     -     -         -            -               -           -     13.17
# 3     -     -         -            -               -           -     13.17
# 4     -     -         -            -               -           -     13.17
#
#    Longitude  RL_MSL Data Acquisition Time  \
# 0      77.57     NaN      22-11-2022 12:00
# 1      77.57     NaN      22-11-2022 18:00
# 2      77.57     NaN      23-11-2022 00:00
# 3      77.57     NaN      23-11-2022 06:00
# 4      77.57     NaN      23-11-2022 12:00
#
#    Groundwater Level Telemetry 6 Hourly (meter)
# 0                                       -24.029
# 1                                       -24.054
# 2                                       -24.047
# 3                                       -24.095
# 4                                       -24.120

# %% [markdown]
# #Check data types and missing values

# %%
print("DATA TYPES")
print(df.dtypes)

print("\nMISSING VALUES")
missing = df.isnull().sum()
print(missing[missing > 0].sort_values(ascending=False))
# Out:
# DATA TYPES
# _id                                               int64
# SlNo                                              int64
# Station                                          object
# Agency                                           object
# State LGD Code                                    int64
# State                                            object
# District LGD Code                                 int64
# District                                         object
# Tehsil                                           object
# Block                                            object
# Village                                          object
# River                                            object
# Basin                                            object
# Tributary                                        object
# Subtributary                                     object
# SubSubtributary                                  object
# Local River                                      object
# Latitude                                        float64
# Longitude                                       float64
# RL_MSL                                          float64
# Data Acquisition Time                            object
# Groundwater Level Telemetry 6 Hourly (meter)    float64
# dtype: object
#
# MISSING VALUES
# RL_MSL    29537
# dtype: int64
